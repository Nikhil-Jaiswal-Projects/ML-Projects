# %%
import pandas as pd

# %%
data = pd.read_csv(r"ML-4 Feature Scaling Resource16994544271 (1).txt")

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
data.describe() # check outliers  using mean and std   is mean is up and std down than no outliers there
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data["Pregnancies"]);

# %%
data.shape
# Out:
# (768, 9)

# %%
data.hist();

# if graph in not in normal foam so use "MIN-MAX-APPROACH"
# if graph is in normal foam so use "STANDARDIZATION"

# %% [markdown]
# # MIN MAX APPROACH

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale = MinMaxScaler()

# %%
scale.fit_transform(data[["Pregnancies","Glucose"]])
# Out:
# array([[0.35294118, 0.74371859],
#        [0.05882353, 0.42713568],
#        [0.47058824, 0.91959799],
#        ...,
#        [0.29411765, 0.6080402 ],
#        [0.05882353, 0.63316583],
#        [0.05882353, 0.46733668]])

# %%
data[["Pregnancies1","Glucose1"]] = scale.fit_transform(data[["Pregnancies","Glucose"]])

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Pregnancies1  Glucose1
# 0                     0.627   50        1      0.352941  0.743719
# 1                     0.351   31        0      0.058824  0.427136
# 2                     0.672   32        1      0.470588  0.919598
# 3                     0.167   21        0      0.058824  0.447236
# 4                     2.288   33        1      0.000000  0.688442

# %%
#check min

# %%
data["Pregnancies"].min()
# Out:
# 0

# %%
data["Pregnancies"].max()
# Out:
# 17

# %%
data["Pregnancies1"].min()
# Out:
# 0.0

# %%
data["Pregnancies1"].max()
# Out:
# 1.0

# %%
# check max

# %%
data["Glucose"].min()
# Out:
# 0

# %%
data["Glucose"].max()
# Out:
# 199

# %%
data["Glucose1"].min()
# Out:
# 0.0

# %%
data["Glucose1"].max()
# Out:
# 1.0

# %%
import seaborn as sns

# %%
plt.subplot(1,2,1)
sns.kdeplot(data["Pregnancies"],color="red")
sns.kdeplot(data["Glucose"],color="green")
plt.title("Before")
#...............................
plt.subplot(1,2,2)
sns.kdeplot(data["Pregnancies1"],color="red")
sns.kdeplot(data["Glucose1"],color="green")
plt.title("After")
#...............................

# it show your scale before and after

# how min max improve data scale
# Out:
# Text(0.5, 1.0, 'After')

# %%
data.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome  Pregnancies1  Glucose1
# 0                     0.627   50        1      0.352941  0.743719
# 1                     0.351   31        0      0.058824  0.427136

# %% [markdown]
# # Standard scale Approach

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale1 = StandardScaler()

# %%
scale1.fit_transform(data[["BloodPressure","SkinThickness"]])
# Out:
# array([[ 0.14964075,  0.90726993],
#        [-0.16054575,  0.53090156],
#        [-0.26394125, -1.28821221],
#        ...,
#        [ 0.14964075,  0.15453319],
#        [-0.47073225, -1.28821221],
#        [ 0.04624525,  0.65635768]])

# %%
s1 = scale1.fit_transform(data[["BloodPressure","SkinThickness"]])

# %%
data[["BloodPressure1","SkinThickness1"]] = s1

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Pregnancies1  Glucose1  \
# 0                     0.627   50        1      0.352941  0.743719
# 1                     0.351   31        0      0.058824  0.427136
# 2                     0.672   32        1      0.470588  0.919598
# 3                     0.167   21        0      0.058824  0.447236
# 4                     2.288   33        1      0.000000  0.688442
#
#    BloodPressure1  SkinThickness1
# 0        0.149641        0.907270
# 1       -0.160546        0.530902
# 2       -0.263941       -1.288212
# ...

# %%
#if value is below the mean than vo negative consider karega and above hui so positiv

# %%
plt.subplot(1,2,1)
sns.kdeplot(data["BloodPressure"],color="red")
sns.kdeplot(data["SkinThickness"],color="green")
plt.title("Before")
#...............................
plt.subplot(1,2,2)
sns.kdeplot(data["BloodPressure1"],color="red")
sns.kdeplot(data["SkinThickness1"],color="green")
plt.title("After")
#...............................
# Out:
# Text(0.5, 1.0, 'After')

# %%
from sklearn.preprocessing import RobustScaler

# %%
scale3 = RobustScaler()

# %%
scale3.fit_transform(data[["Insulin","BMI"]])
# Out:
# array([[-0.23968566,  0.17204301],
#        [-0.23968566, -0.58064516],
#        [-0.23968566, -0.93548387],
#        ...,
#        [ 0.64047151, -0.62365591],
#        [-0.23968566, -0.20430108],
#        [-0.23968566, -0.17204301]])

# %%
data[["Insulin1","BMI1"]] = scale3.fit_transform(data[["Insulin","BMI"]])

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Pregnancies1  Glucose1  \
# 0                     0.627   50        1      0.352941  0.743719
# 1                     0.351   31        0      0.058824  0.427136
# 2                     0.672   32        1      0.470588  0.919598
# 3                     0.167   21        0      0.058824  0.447236
# 4                     2.288   33        1      0.000000  0.688442
#
#    BloodPressure1  SkinThickness1  Insulin1      BMI1
# 0        0.149641        0.907270 -0.239686  0.172043
# ...

# %%
plt.subplot(1,2,1)
sns.kdeplot(data["Insulin"],color="red")
sns.kdeplot(data["BMI"],color="green")
plt.title("Before")
#...............................
plt.subplot(1,2,2)
sns.kdeplot(data["Insulin1"],color="red")
sns.kdeplot(data["BMI1"],color="green")
plt.title("After")
# Out:
# Text(0.5, 1.0, 'After')

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome  \
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...
